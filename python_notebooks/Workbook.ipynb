# %% [markdown]
# ## IS 445 Homework 6

# %% [markdown]
# ---
# author: Seamus Chang
# date: November 14, 2024
# embed-resources: true
# ---

# %%
import pandas as pd
import altair as alt

# %%
url = 'https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_data/main/building_inventory.csv'
df = pd.read_csv(url)

df.head()
# Out:
#                        Agency Name  \
# 0  Department of Natural Resources
# 1  Department of Natural Resources
# 2  Department of Natural Resources
# 3  Department of Natural Resources
# 4  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City  Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria     61501  Fulton             17            Cheri Bustos        93
# 1  Astoria     61501  Fulton             17            Cheri Bustos        93
# 2  Astoria     61501  Fulton             17            Cheri Bustos        93
# ...

# %%
data_filtered = df.dropna(subset=["Square Footage", "Year Constructed", "Bldg Status"])

status_selection = alt.selection_point(
    fields=['Bldg Status'],
    bind=alt.binding_select(options=data_filtered['Bldg Status'].unique().tolist(), name='Select Building Status')
)

chart1 = alt.Chart(data_filtered).mark_circle().encode(
    x=alt.X('County:O', title='County'),
    y=alt.Y('Square Footage:Q', title='Square Footage'),
    color='Agency Name:N', 
    size='Square Footage:Q',  
    tooltip=['Location Name', 'Square Footage', 'Bldg Status', 'Agency Name']
).properties(
    title='Geographical Distribution of Buildings by Agency',
    width=700,
    height=400
).add_params(
    status_selection
).transform_filter(
    status_selection
)

# %%
chart2 = alt.Chart(df).mark_bar().encode(
    x=alt.X('County:O', title='County'),
    y=alt.Y('count():Q', title='Number of Buildings'),
    color='Agency Name:N', 
    tooltip=['Year Constructed', 'count()', 'Agency Name']
).properties(
    title='Construction Trends by County and Agency',
    width=700,
    height=400
)

# %%
myJekyllDir = '/Users/seamuschang/GitHub/seamuschang31.github.io/assets/json/'

# %%
chart1.properties(width='container').save(myJekyllDir + 'geographic_scatter.json')

# %%
chart2.properties(width='container').save(myJekyllDir + 'temporal_bar.json')
